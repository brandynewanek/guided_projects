# %% [markdown]
# # Ensemble Classic Cars MPG Prediction
#
# https://www.kaggle.com/datasets/ankanhore545/classic-cars

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import None
from sklearn.decomposition import None
from sklearn.pipeline import None
from sklearn.ensemble import 'R'None, 'G'None, 'A'None

from sklearn.model_selection import None

# %%
df = pd.read_csv('https://raw.githubusercontent.com/brandynewanek/brandynewanek/main/Cars.csv', sep=';')

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders Displacement Horsepower  Weight  \
# 0  Chevrolet Chevelle Malibu  18,0          8        307,0      130,0    3504
# 1          Buick Skylark 320  15,0          8        350,0      165,0    3693
# 2         Plymouth Satellite  18,0          8        318,0      150,0    3436
# 3              AMC Rebel SST  16,0          8        304,0      150,0    3433
# 4                Ford Torino  17,0          8        302,0      140,0    3449
#
#   Acceleration  Model Origin
# 0         12,0     70     US
# 1         11,5     70     US
# 2         11,0     70     US
# 3         12,0     70     US
# 4         10,5     70     US

# %% [markdown]
# # EDA

# %%
df.None ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    object
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    object
#  4   Horsepower    406 non-null    object
#  5   Weight        406 non-null    int64
#  6   Acceleration  406 non-null    object
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 28.7+ KB

# %%
import matplotlib
None.None.None ('bmh')

# %%
for feat in df.None:
  if df[feat].None == 'object':
    df[feat].None ().None (kind='bar')
  else:
    df[feat].None (kind='hist')
  plt.None (None)
  plt.show()

# %% [markdown]
# **Observations**
#
# + MPG,Displacement, Acceleration, and Horsepower are incorrectly classified as data type object
# + Cylinders, 3 and 5 could be combined to reduce dimensions
# + Weight - Seminormal distribution, small right tail
# + Origin - 3 categories, US, Japan, Europe

# %% [markdown]
# ## Preprocessing 1

# %% [markdown]
# ### Correcting Datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    object
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    object
#  4   Horsepower    406 non-null    object
#  5   Weight        406 non-null    int64
#  6   Acceleration  406 non-null    object
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 28.7+ KB

# %%
for None in df.columns:
  if None[None].dtype == 'object':
    print(df[None].None ())
    print('☻' * 40)
# Out:
# Toyota Corolla                9
# Ford Pinto                    6
# Ford Maverick                 5
# AMC Matador                   5
# Volkswagen Rabbit             5
#                              ..
# Plymouth Grand Fury           1
# Chevrolete Chevelle Malibu    1
# Plymouth Fury                 1
# Buick Skyhawk                 1
# Chevy S-10                    1
# Name: Car, Length: 308, dtype: int64
# ☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻
# 13,0    20
# 14,0    19
# 18,0    17
# 15,0    16
# 26,0    14
#         ..
# 31,9     1
# 16,9     1
# 18,2     1
# 22,3     1
# 44,0     1
# Name: MPG, Length: 130, dtype: int64
# ☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻
# 97,00    22
# 350,0    19
# 98,00    18
# 250,0    17
# 318,0    17
#          ..
# 83,00     1
# 171,0     1
# 115,0     1
# 101,0     1
# 144,0     1
# Name: Displacement, Length: 83, dtype: int64
# ☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻☻
# 150,0    22
# 90,00    20
# 88,00    19
# 110,0    19
# 100,0    17
# ...

# %%
col_chng = ['MPG', 'Displacement', 'Horsepower', 'Acceleration']

# %%
for None in None:
  df[None] = df[None].str.replace(',', '.')
  df[feat] = df[feat].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    int64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.7+ KB

# %% [markdown]
# ## Univariate 2

# %%
for feat in df.columns:
  if df[feat].dtype == 'object':
    df[feat].value_counts().plot(None='bar')
  else:
    df[feat].plot(None='hist')
  plt.title(feat)
  plt.None()

# %% [markdown]
# **Observations**
#
# + MPG - Semi-Normal Distribution with small left tail
# + Cylinders, 3 and 5 could be combined to reduce dimensions
# + Displacement - abnormal exponential distribution
# + Horsepower - Semi Normal Distribution with small left tail
# + Weight - Semi- Uniform distributon small right tail
# + Acceleration - Normal distribution with tails on both sides
# + Model - Semi-Uniform Distribution
# + Origin - category with 3 classes
#
# + MPG - Target appears to have 0 values which should be impossible

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.None (df, None='MPG')

# %%
sns.None(df.None (), None=True, None='mako')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## MPG 0 values

# %%
df['MPG'].plot(kind='hist')

# %%
df[df['MPG'] == 0].shape
# Out:
# (8, 9)

# %% [markdown]
# although there are 8 rows which would normally be too much to drop because it is the target we will drop incorrect target values as to not add bias

# %%
print(df.shape)
df = df[df['MPG'] None 0].copy()
df.shape
# Out:
# (406, 9)
# (398, 9)

# %% [markdown]
# ## Treating Outliers

# %% [markdown]
# ### Horsepower

# %%
df['Horsepower'].plot(kind='hist')

# %%
df['Horsepower'] = df['Horsepower'].None (None=50, None=200)

# %%
df['Horsepower'].plot(kind='hist')

# %% [markdown]
# ### Weight

# %%
df['Weight'].plot(None='hist', None=30)

# %%
df['Weight'] = df['Weight'].None (None=4750)

# %%
df['Weight'].plot(kind='hist', bins=30)

# %% [markdown]
# ### Acceleration

# %%
df['Acceleration'].plot(kind='hist', bins=30)

# %%
None['Acceleration'] = None['Acceleration'].clip(lower=10, upper=22.5)

# %%
df['Acceleration'].plot(kind='hist', bins=30)

# %% [markdown]
# ## Dimension Reduction

# %% [markdown]
# ### Cylinder

# %%
df['Cylinders'].None ().None (kind='bar')

# %%
df['Cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: Cylinders, dtype: int64

# %%
df['Cylinders'] = df['Cylinders'].None ([3,5], 6)

# %%
df['Cylinders'].value_counts().plot(None='bar')

# %% [markdown]
# ## binning continuous

# %%
df['Model'].plot(kind='hist')

# %%
df['Model_cat'] = pd.None (df['Model'], None=[69,73,76,79,83], None=['70-73', '74-76', '77-79', '79-82'])

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1          Buick Skylark 320  15.0          8         350.0       165.0
# 2         Plymouth Satellite  18.0          8         318.0       150.0
# 3              AMC Rebel SST  16.0          8         304.0       150.0
# 4                Ford Torino  17.0          8         302.0       140.0
#
#    Weight  Acceleration  Model Origin Model_cat
# 0    3504          12.0     70     US     70-73
# 1    3693          11.5     70     US     70-73
# 2    3436          11.0     70     US     70-73
# 3    3433          12.0     70     US     70-73
# 4    3449          10.5     70     US     70-73

# %% [markdown]
# ## get_dummies

# %%
df.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin', 'Model_cat'],
#       dtype='object')

# %%
df = pd.None (df, None=['Cylinders', 'Origin', 'Model_cat'])

# %%
df.shape
# Out:
# (398, 17)

# %%
df.head()
# Out:
#                          Car   MPG  Displacement  Horsepower  Weight  \
# 0  Chevrolet Chevelle Malibu  18.0         307.0       130.0    3504
# 1          Buick Skylark 320  15.0         350.0       165.0    3693
# 2         Plymouth Satellite  18.0         318.0       150.0    3436
# 3              AMC Rebel SST  16.0         304.0       150.0    3433
# 4                Ford Torino  17.0         302.0       140.0    3449
#
#    Acceleration  Model  Cylinders_4  Cylinders_6  Cylinders_8  Origin_Europe  \
# 0          12.0     70            0            0            1              0
# 1          11.5     70            0            0            1              0
# 2          11.0     70            0            0            1              0
# 3          12.0     70            0            0            1              0
# 4          10.5     70            0            0            1              0
#
#    Origin_Japan  Origin_US  Model_cat_70-73  Model_cat_74-76  Model_cat_77-79  \
# ...

# %% [markdown]
# # Modeling

# %% [markdown]
# ## train test split

# %%
df.columns
# Out:
# Index(['Car', 'MPG', 'Displacement', 'Horsepower', 'Weight', 'Acceleration',
#        'Model', 'Cylinders_4', 'Cylinders_6', 'Cylinders_8', 'Origin_Europe',
#        'Origin_Japan', 'Origin_US', 'Model_cat_70-73', 'Model_cat_74-76',
#        'Model_cat_77-79', 'Model_cat_79-82'],
#       dtype='object')

# %%
None = [ 'Displacement', 'Horsepower', 'Weight', 'Acceleration',
       'Model', 'Cylinders_4', 'Cylinders_6', 'Cylinders_8', 'Origin_Europe',
       'Origin_Japan', 'Origin_US', 'Model_cat_70-73', 'Model_cat_74-76',
       'Model_cat_77-79', 'Model_cat_79-82']
None = ['MPG']

# %%
None = df[None]
None = df[None]

# %%
X_tr, X_ts, y_tr, y_ts = train_test_split(None, None, test_size=.3, random_state=42)

# %%
print(X_tr.shape)
print(y_tr.shape)
print(X_ts.shape)
print(y_ts.shape)
# Out:
# (278, 15)
# (278, 1)
# (120, 15)
# (120, 1)

# %% [markdown]
# ## StandardScaler and PCA

# %%
std_scaler = None ()
pca = None ()

# %% [markdown]
# ## RandomForest

# %%
rf = make_pipeline(None, None, None ()).fit(X_tr, y_tr)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py:394: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %%
score_tr_rf = rf.None (X_tr,y_tr)
score_ts_rf = rf.None (X_ts,y_ts)
score_tr_rf
# Out:
# 0.9780675015139041

# %%
y_pred_tr_rf = rf.None (X_tr)
y_pred_ts_rf = rf.predict(X_ts)

# %%
sns.None (x=y_tr, y=y_pred_tr_rf).set(title='Residual Plot of Train Predictions')
# Out:
# [Text(0.5, 1.0, 'Residual Plot of Train Predictions')]

# %%
sns.residplot(x=y_ts, y=y_pred_ts_rf).set(title='Residual Plot of Test Predictions')
# Out:
# [Text(0.5, 1.0, 'Residual Plot of Test Predictions')]

# %% [markdown]
# **Observations**
#
# The randomforestregressor looks to make errors target is above the 30 with under predictions happening most often.  And over predicting happen in the mid range values of target 15 to 30.

# %% [markdown]
# ## GradientBoosting

# %%
gb = None (std_scaler, pca, None ()).fit(X_tr, y_tr)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
score_tr_gb = None.score(X_tr,y_tr)
score_ts_gb = None.score(X_ts,y_ts)
score_tr_gb
# Out:
# 0.9819229488353308

# %%
y_pred_tr_gb = gb.predict(X_tr)
y_pred_ts_gb = gb.predict(X_ts)

# %%
sns.residplot(x=y_tr, y=y_pred_tr_gb).None (title='Residual Plot of Train Predictions')
# Out:
# [Text(0.5, 1.0, 'Residual Plot of Train Predictions')]

# %%
sns.residplot(x=y_ts, y=y_pred_ts_gb).None (title='Residual Plot of Test Predictions')
# Out:
# [Text(0.5, 1.0, 'Residual Plot of Test Predictions')]

# %% [markdown]
# **Observations**
#
# + GradientBoosting seems to have the same problem as RandomForest and under predictions higher true values and over predictions mid range values.  Overall predictions seem more weighted to over predicting

# %% [markdown]
# ## AdaBoost

# %%
ada = make_pipeline(std_scaler, pca, None ()).fit(X_tr, y_tr)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
score_tr_ada = ada.score(X_tr,y_tr)
score_ts_ada = ada.score(X_ts,y_ts)
score_tr_ada
# Out:
# 0.9145151312397343

# %%
y_pred_tr_ada = ada.predict(X_tr)
y_pred_ts_ada = ada.predict(X_ts)

# %%
sns.residplot(x=y_tr, y=y_pred_tr_ada).set(title='Residual Plot of Train Predictions')
# Out:
# [Text(0.5, 1.0, 'Residual Plot of Train Predictions')]

# %%
sns.residplot(x=y_ts, y=y_pred_ts_ada).set(title='Residual Plot of Test Predictions')
# Out:
# [Text(0.5, 1.0, 'Residual Plot of Test Predictions')]

# %% [markdown]
# **Observations**
#
# Has large variation in predictions.  Generally AdaBoost's predictions seem less accurate.

# %% [markdown]
# ## Models Summary

# %%
None = [score_tr_rf, None, None]
ts_scores = [score_ts_rf, score_ts_gb, score_ts_ada]
models = [None, 'gradientboost', 'adaptiveboost']
dict_scores = {'train_score':None, 'test_score':ts_scores}

pd.None (None, None=models).sort_values('test_score', None=False)
# Out:
#                train_score  test_score
# randomforest      0.978068    0.889679
# adaptiveboost     0.914515    0.874352
# gradientboost     0.981923    0.872829

# %% [markdown]
# # What hyperparameters could we change to enhance model
#
# our model appears to be overfitting try and find parameters that that reduce the train score and this should improve our test scores by reducing overfitting, making a model more general helps prevent us from capturing noise in our model and having a model that would preform poorly on new unseen data
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html

# %%
rf = make_pipeline(std_scaler, pca, RandomForestRegressor(n_estimators=180, max_depth=6,
                                                          min_samples_split=5, 
                                                          max_samples=.90,
                                                          random_state=42)).fit(X_tr, y_tr)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py:394: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %%
rf.score(X_ts, y_ts)
# Out:
# 0.8889330026795346
